# %% [markdown]
# # Creating a supercell with ASE
#
# Supercells are used for simulations where one isn't necessarily interested in perfect crystalline bulk conditions, but instead impurities in materials or processes on/in a catalyst, such as adsorption.
#
# Creating a supercell with ASE is super easy as you can multiple the unit cell by vectors. Lets start by building a simple Pd bulk system:

# %%
from ase.build import bulk

atoms = bulk('Pd', crystalstructure='fcc', a=3.909)

# %% [markdown]
# The `atoms` object now holds our bulk Pd unit cell. We can view this by using the `visualize` module in ASE:

# %%
from ase.visualize import view

view(atoms, viewer='x3d')
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D style="margin:0; padding:0; width:100%; height:100%; border:none;">
#
#    <Scene>
#
#     <Transform translation="0.00 0.00 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#    </Scene>
#
#   </X3D>
#
#  </body>
#
# </html>

# %% [markdown]
# To now create a supercell, we just need to apply the vector transformation

# %%
supercell = atoms*(3,3,3)

# %% [markdown]
# Which can be subsequently viewed as:

# %%
view(supercell, viewer='x3d')
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D style="margin:0; padding:0; width:100%; height:100%; border:none;">
#
#    <Scene>
#
#     <Transform translation="0.00 0.00 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.95 1.95 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.91 3.91 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.95 0.00 1.95">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.91 1.95 1.95">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.86 3.91 1.95">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.91 0.00 3.91">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.86 1.95 3.91">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="7.82 3.91 3.91">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.00 1.95 1.95">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.95 3.91 1.95">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.91 5.86 1.95">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.95 1.95 3.91">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.91 3.91 3.91">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.86 5.86 3.91">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.91 1.95 5.86">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.86 3.91 5.86">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="7.82 5.86 5.86">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.00 3.91 3.91">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.95 5.86 3.91">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.91 7.82 3.91">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.95 3.91 5.86">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.91 5.86 5.86">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.86 7.82 5.86">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.91 3.91 7.82">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.86 5.86 7.82">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="7.82 7.82 7.82">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.000 0.412 0.522" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.39">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#    </Scene>
#
#   </X3D>
#
#  </body>
